# %%
# RUN THIS CELL TO INSTALL THE REQUIRED PACKAGES
# !pip install https://github.com/maciejkula/spotlight/archive/master.zip
# Out:
# Collecting https://github.com/maciejkula/spotlight/archive/master.zip
#   Downloading https://github.com/maciejkula/spotlight/archive/master.zip
#      \ 372.5 kB 7.2 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spotlight==0.1.6) (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->spotlight==0.1.6) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->spotlight==0.1.6) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->spotlight==0.1.6) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->spotlight==0.1.6) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->spotlight==0.1.6) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->spotlight==0.1.6) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=0.4.0->spotlight==0.1.6) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->spotlight==0.1.6) (3.0.2)
# Building wheels for collected packages: spotlight
#   Building wheel for spotlight (setup.py) ... done
#   Created wheel for spotlight: filename=spotlight-0.1.6-py3-none-any.whl size=33895 sha256=ff1b60f20fa46b362ae95526536913301b6d0fa919dcfae71cc0969e0a231da1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7nt53pi2/wheels/97/29/2a/deeace90d6276201702ba614d15ccb6569acf1863478dd3f15
# Successfully built spotlight
# Installing collected packages: spotlight
# Successfully installed spotlight-0.1.6

# %%
from spotlight.datasets.movielens import get_movielens_dataset

dataset = get_movielens_dataset(variant='100K')
dataset
# Out:
# <Interactions dataset (944 users x 1683 items x 100000 interactions)>

# %%
import pandas as pd

df = pd.DataFrame({
    'user_id': dataset.user_ids,
    'item_id': dataset.item_ids,
    'rating': dataset.ratings,
    'timestamp': dataset.timestamps
})

df
# Out:
#        user_id  item_id  rating  timestamp
# 0          196      242     3.0  881250949
# 1          186      302     3.0  891717742
# 2           22      377     1.0  878887116
# 3          244       51     2.0  880606923
# 4          166      346     1.0  886397596
# ...        ...      ...     ...        ...
# 99995      880      476     3.0  880175444
# 99996      716      204     5.0  879795543
# 99997      276     1090     1.0  874795795
# 99998       13      225     2.0  882399156
# 99999       12      203     3.0  879959583
#
# [100000 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# user_id      0
# item_id      0
# rating       0
# timestamp    0
# dtype: int64

# %% [markdown]
# I would like to see how many movies each user has rated

# %%
# Count the number of ratings for each user
ratings_count = df.groupby('user_id').size().reset_index(name='Rating_Count')

# Merge the ratings count back into the original DataFrame
df = df.merge(ratings_count, on='user_id', how='left')
df
# Out:
#        user_id  item_id  rating  timestamp  Rating_Count
# 0          196      242     3.0  881250949            39
# 1          186      302     3.0  891717742            92
# 2           22      377     1.0  878887116           128
# 3          244       51     2.0  880606923           238
# 4          166      346     1.0  886397596            20
# ...        ...      ...     ...        ...           ...
# 99995      880      476     3.0  880175444           368
# 99996      716      204     5.0  879795543           269
# 99997      276     1090     1.0  874795795           518
# 99998       13      225     2.0  882399156           636
# 99999       12      203     3.0  879959583            51
#
# [100000 rows x 5 columns]

# %% [markdown]
# #### Observations and Ideas about the Dataset
#
# A good idea would be to cluster users with similar ranks for the same movies. In this way we can have an idea of what other movies will someone new like if he also like some of a specific cluster.

# %% [markdown]
# # Data visualization and exploration
#
# Lets have a look on the distribution of Ratings first

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
df['rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Identify the top 10 users with the highest Rating_Count
top_10_users = df.groupby('user_id')['Rating_Count'].max().nlargest(10)

# Plot
plt.figure(figsize=(10, 6))
top_10_users.plot(kind='bar', color='lightblue')

plt.title('Top 10 Users with the Most Votes (Ratings Count)')
plt.xlabel('User ID')
plt.ylabel('Number of Ratings')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
for user_id in top_10_users:
    print(f"Top 10 Movies for User {user_id}:")

    # Filter the data for the current user
    user_ratings = df[df['user_id'] == user_id]

    # Count the number of times each movie (item_id) has been rated by this user
    top_10_movies = user_ratings['item_id'].value_counts().nlargest(10)

    # Print the top 10 movies (item_id and their counts)
    for rank, (movie_id, count) in enumerate(top_10_movies.items(), start=1):
        print(f"{rank}. Movie ID: {movie_id} - Rated {count} times")

    print("\n" + "-" * 40)  # Print a separator between users
# Out:
# Top 10 Movies for User 405:
# 1. Movie ID: 56 - Rated 1 times
# 2. Movie ID: 794 - Rated 1 times
# 3. Movie ID: 770 - Rated 1 times
# 4. Movie ID: 851 - Rated 1 times
# 5. Movie ID: 1441 - Rated 1 times
# 6. Movie ID: 438 - Rated 1 times
# 7. Movie ID: 659 - Rated 1 times
# 8. Movie ID: 1147 - Rated 1 times
# 9. Movie ID: 745 - Rated 1 times
# 10. Movie ID: 45 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 655:
# 1. Movie ID: 274 - Rated 1 times
# 2. Movie ID: 31 - Rated 1 times
# 3. Movie ID: 902 - Rated 1 times
# 4. Movie ID: 118 - Rated 1 times
# 5. Movie ID: 566 - Rated 1 times
# 6. Movie ID: 658 - Rated 1 times
# 7. Movie ID: 1161 - Rated 1 times
# 8. Movie ID: 942 - Rated 1 times
# 9. Movie ID: 6 - Rated 1 times
# 10. Movie ID: 912 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 13:
# 1. Movie ID: 526 - Rated 1 times
# 2. Movie ID: 736 - Rated 1 times
# 3. Movie ID: 492 - Rated 1 times
# 4. Movie ID: 638 - Rated 1 times
# 5. Movie ID: 895 - Rated 1 times
# 6. Movie ID: 657 - Rated 1 times
# 7. Movie ID: 179 - Rated 1 times
# 8. Movie ID: 636 - Rated 1 times
# 9. Movie ID: 86 - Rated 1 times
# 10. Movie ID: 865 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 450:
# 1. Movie ID: 470 - Rated 1 times
# 2. Movie ID: 476 - Rated 1 times
# 3. Movie ID: 715 - Rated 1 times
# 4. Movie ID: 648 - Rated 1 times
# 5. Movie ID: 1053 - Rated 1 times
# 6. Movie ID: 602 - Rated 1 times
# 7. Movie ID: 1521 - Rated 1 times
# 8. Movie ID: 431 - Rated 1 times
# 9. Movie ID: 693 - Rated 1 times
# 10. Movie ID: 167 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 276:
# 1. Movie ID: 796 - Rated 1 times
# 2. Movie ID: 356 - Rated 1 times
# 3. Movie ID: 453 - Rated 1 times
# 4. Movie ID: 523 - Rated 1 times
# 5. Movie ID: 1118 - Rated 1 times
# 6. Movie ID: 9 - Rated 1 times
# 7. Movie ID: 281 - Rated 1 times
# 8. Movie ID: 201 - Rated 1 times
# 9. Movie ID: 274 - Rated 1 times
# 10. Movie ID: 47 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 416:
# 1. Movie ID: 125 - Rated 1 times
# 2. Movie ID: 500 - Rated 1 times
# 3. Movie ID: 843 - Rated 1 times
# 4. Movie ID: 216 - Rated 1 times
# 5. Movie ID: 200 - Rated 1 times
# 6. Movie ID: 42 - Rated 1 times
# 7. Movie ID: 97 - Rated 1 times
# 8. Movie ID: 1469 - Rated 1 times
# 9. Movie ID: 781 - Rated 1 times
# 10. Movie ID: 172 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 537:
# 1. Movie ID: 28 - Rated 1 times
# 2. Movie ID: 714 - Rated 1 times
# 3. Movie ID: 837 - Rated 1 times
# 4. Movie ID: 129 - Rated 1 times
# 5. Movie ID: 277 - Rated 1 times
# 6. Movie ID: 647 - Rated 1 times
# 7. Movie ID: 789 - Rated 1 times
# 8. Movie ID: 305 - Rated 1 times
# 9. Movie ID: 478 - Rated 1 times
# 10. Movie ID: 750 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 303:
# 1. Movie ID: 785 - Rated 1 times
# 2. Movie ID: 443 - Rated 1 times
# 3. Movie ID: 150 - Rated 1 times
# 4. Movie ID: 583 - Rated 1 times
# 5. Movie ID: 402 - Rated 1 times
# 6. Movie ID: 1092 - Rated 1 times
# 7. Movie ID: 82 - Rated 1 times
# 8. Movie ID: 85 - Rated 1 times
# 9. Movie ID: 251 - Rated 1 times
# 10. Movie ID: 22 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 234:
# 1. Movie ID: 1184 - Rated 1 times
# 2. Movie ID: 141 - Rated 1 times
# 3. Movie ID: 418 - Rated 1 times
# 4. Movie ID: 277 - Rated 1 times
# 5. Movie ID: 923 - Rated 1 times
# 6. Movie ID: 504 - Rated 1 times
# 7. Movie ID: 489 - Rated 1 times
# 8. Movie ID: 166 - Rated 1 times
# 9. Movie ID: 215 - Rated 1 times
# 10. Movie ID: 636 - Rated 1 times
#
# ----------------------------------------
# Top 10 Movies for User 393:
# 1. Movie ID: 1219 - Rated 1 times
# 2. Movie ID: 1034 - Rated 1 times
# 3. Movie ID: 5 - Rated 1 times
# 4. Movie ID: 135 - Rated 1 times
# 5. Movie ID: 369 - Rated 1 times
# 6. Movie ID: 393 - Rated 1 times
# 7. Movie ID: 501 - Rated 1 times
# 8. Movie ID: 86 - Rated 1 times
# 9. Movie ID: 65 - Rated 1 times
# 10. Movie ID: 944 - Rated 1 times
#
# ----------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

five_star_ratings = df[df['rating'] == 5]

# Step 2: Count how many times each movie (item_id) got a 5-star rating
five_star_movie_counts = five_star_ratings['item_id'].value_counts()

# Step 3: Get the top 10 movies with the highest number of 5-star ratings
top_10_movies_5_star = five_star_movie_counts.nlargest(10)

# Step 4: Plot the distribution of the top 10 movies with 5-star ratings
plt.figure(figsize=(10, 6))
top_10_movies_5_star.plot(kind='bar', color='lightcoral')

plt.title('Top 10 Movies with the Most 5-Star Ratings')
plt.xlabel('Movie (item_id)')
plt.ylabel('Number of 5-Star Ratings')
plt.xticks(rotation=45, ha='right')
plt.show()
